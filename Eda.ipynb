# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# %cd /gdrive/My Drive/Universidad/Ciclo 2021-1/Prueba
# Out:
# /gdrive/My Drive/Universidad/Ciclo 2021-1/Prueba

# %%
# %ls
# Out:
# ConfigGit.ipynb  Eda.ipynb  loan200.csv  loan3000.csv  loan_data.csv.gz

# %% [markdown]
# # Hola Esto es una prueba para ver si funciona todo

# %%
print("Hola esto es una prueba de Colab, Google Drive, GitHub")
# Out:
# Hola esto es una prueba de Colab, Google Drive, GitHub
